# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
#data loading and splitting
data=pd.read_csv("Dataset_Fish_Market.csv")

X = data.drop("Species", axis=1)
Y = data["Species"]

scaler = StandardScaler()
X = scaler.fit_transform(X)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.5, random_state=0)

# %%
models = {
    'SVM (RBF Kernel)': SVC(kernel='rbf', probability=True, random_state=0, gamma=1, C=1),
    'Logistic Regression': LogisticRegression(solver='liblinear', random_state=0),
    'Random Forest': DecisionTreeClassifier(random_state=0)
}

print("=== Performance on Original Data ===")
for name, model in models.items():
    model.fit(X_train, Y_train)
    Y_pred = model.predict(X_test)
    
    print(f"\nModel: {name}")
    print("Accuracy:", metrics.accuracy_score(Y_test, Y_pred))
    print("Recall Macro:", metrics.recall_score(Y_test, Y_pred, average='macro'))
    print("Precision Macro:", metrics.precision_score(Y_test, Y_pred, average='macro'))
    
    print("Recall Micro:", metrics.recall_score(Y_test, Y_pred, average='micro'))
    print("Precision Micro:", metrics.precision_score(Y_test, Y_pred, average='micro'))
    
    print("Recall :", metrics.recall_score(Y_test, Y_pred, average='weighted'))
    print("Precision:", metrics.precision_score(Y_test, Y_pred, average='weighted'))
    print("Confusion Matrix:\n", confusion_matrix(Y_test, Y_pred))
    print("Classification Report:\n", classification_report(Y_test, Y_pred))
# Out:
# === Performance on Original Data ===
#
# Model: SVM (RBF Kernel)
# Accuracy: 0.725
# Recall Macro: 0.5705840957072484
# Precision Macro: 0.6273809523809524
# Recall Micro: 0.725
# Precision Micro: 0.725
# Recall : 0.725
# Precision: 0.6638541666666666
# Confusion Matrix:
#  [[14  0  0  0  0  0  0]
#  [ 1  3  3  0  0  0  0]
#  [ 0  0 28  0  0  1  0]
#  [ 0  0  4  6  0  0  0]
#  [ 0  0 10  0  0  0  0]
#  [ 0  0  0  0  0  7  0]
#  [ 0  0  3  0  0  0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        Bream       0.93      1.00      0.97        14
#       Parkki       1.00      0.43      0.60         7
#        Perch       0.58      0.97      0.73        29
#         Pike       1.00      0.60      0.75        10
#        Roach       0.00      0.00      0.00        10
#        Smelt       0.88      1.00      0.93         7
#    Whitefish       0.00      0.00      0.00         3
#
#     accuracy                           0.72        80
#    macro avg       0.63      0.57      0.57        80
# weighted avg       0.66      0.72      0.66        80
#
#
# Model: Logistic Regression
# Accuracy: 0.725
# Recall Macro: 0.5460942997888811
# Precision Macro: 0.45098039215686275
# Recall Micro: 0.725
# Precision Micro: 0.725
# Recall : 0.725
# Precision: 0.5691176470588235
# Confusion Matrix:
#  [[14  0  0  0  0  0  0]
#  [ 3  0  0  0  2  2  0]
#  [ 0  0 28  0  0  1  0]
#  [ 0  0  0 10  0  0  0]
#  [ 0  0 10  0  0  0  0]
#  [ 0  0  1  0  0  6  0]
#  [ 0  0  3  0  0  0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        Bream       0.82      1.00      0.90        14
#       Parkki       0.00      0.00      0.00         7
#        Perch       0.67      0.97      0.79        29
#         Pike       1.00      1.00      1.00        10
#        Roach       0.00      0.00      0.00        10
#        Smelt       0.67      0.86      0.75         7
#    Whitefish       0.00      0.00      0.00         3
#
#     accuracy                           0.72        80
#    macro avg       0.45      0.55      0.49        80
# weighted avg       0.57      0.72      0.63        80
#
#
# Model: Random Forest
# Accuracy: 0.625
# Recall Macro: 0.571850809289233
# Precision Macro: 0.6530883367839889
# Recall Micro: 0.625
# Precision Micro: 0.625
# Recall : 0.625
# Precision: 0.702697765700483
# Confusion Matrix:
#  [[14  0  0  0  0  0  0]
#  [ 0  2  0  0  5  0  0]
#  [ 1  0 15  1  8  1  3]
#  [ 0  0  2  8  0  0  0]
#  [ 0  0  4  0  4  0  2]
#  [ 0  0  0  0  0  7  0]
#  [ 0  0  2  0  1  0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#        Bream       0.93      1.00      0.97        14
#       Parkki       1.00      0.29      0.44         7
#        Perch       0.65      0.52      0.58        29
#         Pike       0.89      0.80      0.84        10
#        Roach       0.22      0.40      0.29        10
#        Smelt       0.88      1.00      0.93         7
#    Whitefish       0.00      0.00      0.00         3
#
#     accuracy                           0.62        80
#    macro avg       0.65      0.57      0.58        80
# weighted avg       0.70      0.62      0.64        80
# c:\Users\intel\Desktop\UniCourses\ai cep\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\intel\Desktop\UniCourses\ai cep\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\intel\Desktop\UniCourses\ai cep\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\intel\Desktop\UniCourses\ai cep\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\intel\Desktop\UniCourses\ai cep\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\intel\Desktop\UniCourses\ai cep\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\intel\Desktop\UniCourses\ai cep\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\intel\Desktop\UniCourses\ai cep\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\intel\Desktop\UniCourses\ai cep\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\intel\Desktop\UniCourses\ai cep\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
